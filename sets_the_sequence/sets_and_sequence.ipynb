# %% [markdown]
# ## __1.__ Представьте в виде __несократимой__ рациональной дроби:
#
# ### $$а)\,\,\, 0.(216);$$
#
# ### $$б)\,\,\, 1.0(01).$$

# %% [markdown]
# ## Решение:
# ### $$ \,\,\, а)\,\,\, a = 0.(216) $$
# ### $$ \,\,\, 1000 * a = 216(216) $$
# ### $$ \,\,\, 1000a = 216 + 0.(216) $$
# ### $$ \,\,\, 1000a = 216 + a $$
# ### $$ \,\,\, 999a = 216 $$
# ### $$ \,\,\, a = \frac{216}{999} $$
# ### $$ \,\,\, a = \frac{8}{37} $$
#
# ### $$ \,\,\, б)\,\,\, a = 1.0(01) $$
# ### $$ \,\,\,\,\,\, 10*a = 10(01) $$
# ### $$ \,\,\,\,\,\, 10a = 10 + 0.(01) $$
# ### $$ \,\,\,\,\,\, пусть \,\, b = 0.(01) $$
# ### $$ \,\,\,\,\,\, пусть \,\, 100*b = 1 + 0.(01) $$
# ### $$ \,\,\,\,\,\,\,\, 100*b = 1 + b $$
# ### $$ \,\,\,\,\,\,\,\, b = \frac{1}{99} $$
# ### $$ \,\,\,\,\,\, 10a = 10 + \frac{1}{99} $$
# ### $$ \,\,\,\,\,\, 10a = \frac{991}{99} $$
# ### $$ \,\,\,\,\,\, a = \frac{991}{990}  \,\,\,\,\,или\,\,\,\,а = 1 \frac{1}{990}$$

# %% [markdown]
# ### __2*.__ Пусть $x =\frac{2}{21}$. Известно, что для некоторого натурального $k$ число $x$ записывается в $k$ - ичной системе счисления как $0.(13)_k = 0, 131313..._k$. Найдите $k$.
# ### $$0,(13) = 0,13 + 0,0013 + 0,000013 = 0,13*(1 + 0,01 + 0,0001 + ...) = 0,13 * 1 / (1 - 10^{-2}) = $$
# ### $$ = \frac{13}{10^2 -1} = \frac {13}{99}$$
# #### Переведем в десятичную систему:
# ### $$ \frac{2}{21} = \frac{k+3}{9k+9} $$
# ### $$ 3k = -45$$
# ### $$ k = -15$$
# Понимаю, что не правилльно, но не могу понять где я не правильно рассуждаю ((((((((

# %% [markdown]
# ### __3.__ Проверьте любым способ, является ли данные логические формулы тавтологией:
#
# ### $$a)\,\,\, (A \vee B) \rightarrow (B \vee\overline A)$$
# ### $$б)\,\,\, A \rightarrow (A \vee (\overline B \wedge A))$$
# ### Решение:
# ### $$a)\,\,\, (A \vee B) \rightarrow (B \vee\overline A )=\overline{(A \vee B)} \vee(B \vee \overline A) =(\overline A \wedge \overline B) \vee(B \vee \overline A) = ((\overline A \wedge \overline B) \vee B) \wedge ((\overline A \wedge \overline B) \vee \overline A) = $$
# ### $$ = ((\overline A \wedge \overline B) \vee B) \wedge  \overline A = (\overline A \wedge B) \vee ( \overline A \vee (\overline A \wedge \overline B)) = (\overline A \wedge B) \vee  \overline A = \overline A - не \,тавтолгия$$
#
# ### $$б)\,\,\, A \rightarrow (A \vee (\overline B \wedge A)) = \overline A \vee (A \vee (\overline B \wedge A)) = \overline A \vee A = 1 - тавтология$$

# %% [markdown]
# ### __4.__ Сформулируйте словесно высказывания:
# ### $$a)\,\,\, (\overline A \vee B) \rightarrow \overline C$$
# ### $$б)\,\,\, C \rightarrow (A \vee \overline B)$$
#
# - $A:\,\,\,$ сегодня светит солнце;
# - $B:\,\,\,$ сегодня сыро;
# - $C:\,\,\,$ я поеду на дачу.
# ### Решение:
# ### $$a)\,\,\, (\overline A \vee B) \rightarrow \overline C - Если\,сегодня\,не\,светит\,солнце\,или\,сегодня\,сыро,\,то\,я\,не\,поеду\,на\,дачу $$
#
# ### $$б)\,\,\, C \rightarrow (A \vee \overline B) - Если\,я\,поеду\,на\,дачу,\,то\,сегодня\,светит\,солнце\,или\,сегодня \,не\,сыро $$

# %% [markdown]
# ### __5.__  Пользуясь правилом построения противоположного высказывания, запишите утверждения, противоположные следующим:
#
# a) На любом курсе каждого факультета есть студенты, сдающие все экзамены на «отлично».
#
# б) В любом самолете на рейсе Вашингтон-Москва присутствует хотя бы один сотрудник силовых органов, в каждой пуговице одежды которого вмонтирован микрофон.
#
# ### Решение:
# #### a) На любом курсе каждого факультета есть студенты, сдающие все экзамены на «отлично».
#
# ##### $\forall$ курсе $\forall$ факультета $\exists$ студенты, сдающие $\forall$ экзамены на отлично.
# ##### Противоположное : $\exists$ курс $\exists$ факультет $\forall$ студенты, сдающие $\exists$ экзамен на отлично.
#
# #### б) В любом самолете на рейсе Вашингтон-Москва присутствует хотя бы один сотрудник силовых органов, в каждой пуговице одежды которого вмонтирован микрофон.
# ##### $\forall$ самолете  рейса Вашингтон-Москва $\exists$ сотрудник силовых органов $\forall$ пуговице одежды которого вмонтирован микрофон.
# ##### Противоположное : $\exists$ самолет  рейса Вашингтон-Москва $\forall$ сотрудники силовых органов $\exists$ пуговицу, в которую вмонтирован микрофон.

# %% [markdown]
# ### __6*.__ Прочитайте высказывания, установите их истинность и постройте отрицания:
#
# ### $$a)\,\,\, \forall x\in\mathbb{R}\,\,\,\exists X\in\mathbb{R}:\,\,\, X>x;$$
# ### $$б)\,\,\, \forall y\in\Bigl[0; \frac{\pi}{2}\Bigr]\,\,\,\exists \varepsilon>0:\,\,\, \sin y<\sin(y+\varepsilon);$$
# ### $$в)\,\,\, \forall y\in\Bigl[0; \frac{\pi}{2}\Bigr)\,\,\,\exists \varepsilon>0:\,\,\, \cos y>\cos(y+\varepsilon).$$

# %% [markdown]
# ### Решение:
# ### $$a)\,\,\, \forall x\in\mathbb{R}\,\,\,\exists X\in\mathbb{R}:\,\,\, X>x;$$
# #### Истинное высказывание т.к. во множестве действительных чисел всегда найдется элемент больше любого другого элемента.
# ### $$Отрицание:\,\,\, \exists x\in\mathbb{R}\,\,\,\forall X\in\mathbb{R}:\,\,\, x\geq X$$

# %% [markdown]
# ### $$б)\,\,\, \forall y\in\Bigl[0; \frac{\pi}{2}\Bigr]\,\,\,\exists \varepsilon>0:\,\,\, \sin y<\sin(y+\varepsilon);$$
# #### Ложное  высказывание т.к. в $\frac{\pi}{2}$ функция принимает максимальное значение, значит неравенство $sin \frac{\pi}{2}<\sin(\frac{\pi}{2}+\varepsilon);$ не верно
# ### $$Отрицание:\,\,\, \exists y\in\Bigl[0; \frac{\pi}{2}\Bigr]\,\,\,\forall \varepsilon>0:\,\,\, \sin y\geq \sin(y+\varepsilon);$$

# %% [markdown]
# ### $$в)\,\,\, \forall y\in\Bigl[0; \frac{\pi}{2}\Bigr)\,\,\,\exists \varepsilon>0:\,\,\, \cos y>\cos(y+\varepsilon).$$
# #### Истинное высказывание т.к. на этом полуинтервале функция cos убывает.
# ### $$Отрицание:\,\,\, \exists y\in\Bigl[0; \frac{\pi}{2}\Bigr)\,\,\,\forall \varepsilon>0:\,\,\, \cos y \leq \cos(y+\varepsilon).$$
